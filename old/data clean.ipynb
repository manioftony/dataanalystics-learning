# %%
import pandas as pd
from matplotlib import pyplot as plt 

data = pd.read_csv("https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/imdb_1000.csv")
crime_data = data[data['genre']=='Crime']
greatethen8 = crime_data[crime_data['star_rating']>=5.0]
plt.plot(greatethen8['star_rating'],greatethen8['duration'])
plt.show()

# %%
plt.plot(greatethen8['star_rating'],greatethen8['duration'])
plt.show()

# %%
plt.plot(greatethen8['star_rating'],greatethen8['duration'])

# %%
new = data['star_rating'] + data['duration']
data['total']=new
data.to_csv("manikandan.csv")

# %%
plt.plot(data['star_rating'],data['total'],) 
plt.xlabel("start rating")  
plt.ylabel("Total")


# function to show the plot 
plt.show()

# %%
data

# from selenium import webdriver
# from selenium.webdriver.support.ui import WebDriverWait
# from selenium.webdriver.support.ui import Select
# from selenium.webdriver.common.by import By
# from selenium.webdriver.support import expected_conditions
# from selenium.common.exceptions import NoSuchElementException
# import selenium
# import requests
# import bs4
# import time
# import pandas as pd


# li  = []
# driver = selenium.webdriver.Chrome(executable_path='/home/manikandan/Downloads/chromedriver')
# driver.get('http://results.eci.gov.in/pc/en/constituencywise/ConstituencywiseU011.htm?ac=1')
# for i in range(1,37):
#     obj = Select(driver.find_element_by_id('ddlState'))
#     obj.select_by_index(i)
#     for  j in range(1,ind[i]+1):
#         print(i,j)
#         obj1 = Select(driver.find_element_by_id('ddlAC'))
#         obj1.select_by_index(j)
#         html = driver.page_source
#         #print(html)
#         soup = bs4.BeautifulSoup(html,'html.parser')
#         #soup.prettify()
#         for con in soup.find_all('th',attrs={"align":"center","colspan":"9"}):
#             if '-' in con.text.strip():
#                 cons = con.text.strip().split('-')[1]
#                 sta = con.text.strip().split('-')[0]
#         print(cons)
#         for k in soup.find_all('tr',attrs={"style":"font-size:12px;"}):
#             li_1 = []
#             for l in k.findAll('td'):
#                 li_1.append(l.text)
#             li_1.append(sta)
#             li_1.append(cons)
#             li.append(li_1)
# result = pd.DataFrame(li)
# Out:
#      star_rating                                              title  \
# 0            9.3                           The Shawshank Redemption
# 1            9.2                                      The Godfather
# 2            9.1                             The Godfather: Part II
# 3            9.0                                    The Dark Knight
# 4            8.9                                       Pulp Fiction
# 5            8.9                                       12 Angry Men
# 6            8.9                     The Good, the Bad and the Ugly
# 7            8.9      The Lord of the Rings: The Return of the King
# 8            8.9                                   Schindler's List
# 9            8.9                                         Fight Club
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# ...

# %%
import psycopg2 as pg
import pandas.io.sql as psql
import pandas as pd
connection = pg.connect("host='localhost' dbname=kencloud_prod8 user=postgres password='root'")
#dataframe = psql.DataFrame("SELECT * FROM category", connection)
# df = pd.read_sql_query('select * from student_management_studentenrolldetails',con=connection)
# df = pd.read_sql_query('select * from auth_user where id=155',con=connection)



df = pd.read_sql_query('''
                       select s.passcode,a.username FROM student_management_studentenrolldetails as s INNER JOIN auth_user as a ON
                       a.id=s.user_id''',con=connection)


df.to_json()
# Out:
# '{"passcode":{"0":803325,"1":228323,"2":951881,"3":334172,"4":448573,"5":894618,"6":866289,"7":359054,"8":703429,"9":398535,"10":878595,"11":288645,"12":420814,"13":768655,"14":204207,"15":753085,"16":672076,"17":592701,"18":728444,"19":598871,"20":657909,"21":585412,"22":361696,"23":634195,"24":413502,"25":732041,"26":234526,"27":327586,"28":432114,"29":578389,"30":804901,"31":465819,"32":272378,"33":628118,"34":666747,"35":756386,"36":895579,"37":301226,"38":619115,"39":730036,"40":295468,"41":581862,"42":819759,"43":172997,"44":666002,"45":780896,"46":658879,"47":462456,"48":573708,"49":918371,"50":285367,"51":961894,"52":558001,"53":522384,"54":927524,"55":817451,"56":251612,"57":534576,"58":592932,"59":996519,"60":740231,"61":523936,"62":187698,"63":207049,"64":637284,"65":111854,"66":750886,"67":243514,"68":951611,"69":535396,"70":611948,"71":946287,"72":596424,"73":429814,"74":871648,"75":695418,"76":454575,"77":723677,"78":647337,"79":980758,"80":923968,"81":165618,"82":90516
# ...

# %%
def primid(n):
    for i in range(n+1):
        print (' '*(n-i),'* '*i)

# %%
for i in range(10):
#     print (end=' ')
    print (' '*(10-i),'* '*i)
# Out:
#
#           *
#          * *
#         * * *
#        * * * *
#       * * * * *
#      * * * * * *
#     * * * * * * *
#    * * * * * * * *
#   * * * * * * * * *

# %%
primid(5)
# Out:
#
#      *
#     * *
#    * * *
#   * * * *
#  * * * * *
